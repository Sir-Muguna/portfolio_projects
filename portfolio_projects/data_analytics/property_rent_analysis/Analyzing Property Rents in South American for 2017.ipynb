# %% [markdown]
# # Property Rents Analysis in South America in 2017.
# ### An Exploratory Data Analysis using SQL and PowerBI for visualization.
# ![Flag_map_of_South_America.png](attachment:Flag_map_of_South_America.png)
#
# South America occupies the southern part of the Americas. It is one of the most diverse continents on Earth and is home to many species of animals in the Amazon rainforests.  The continent is home to the world’s highest waterfall, the Angel falls and largest river by volume, the Amazon River. Some of the most industrialized countries in the continent are Brazil, Argentina, Chile, Columbia, Venezuela and Uruguay. These countries alone account for more than 75% of the region’s economy.
#
# History shows that the pursuit of property in Latin America by the colonists was framed by European legal and moral traditions. These imported property systems were established to surmount- the local system of communal property and accommodate the colonizers’ economic interests. With the changing times, the scope and application of property rights has seen changes driven by political and economic environments, with public and social concerns also informing the review, enactment and application of property rights.
#
# Latin America is seeing a boom in non-traditional real estate marketplaces and a surge in investor capital to back them. In this project I will be looking at property rent across Argentina, Brazil, Chile, Columbia, Mexico, Peru and Uruguay for the year 2017.

# %% [markdown]
# ## Data Collection & Cleaning.
# To find the data, I used BigQuery's public dataset portal. The data was available in excel format which I downloaded to my pc and later cleaned it it using power query and merged the different excel tables for each country into one data table. I recently checked the portal and the data is nolonger available.
#
# ![cleaned_data.jpg](attachment:cleaned_data.jpg)

# %% [markdown]
# ### Create database and table for the cleaned_data in PostgreSQL

# %%
# create database for property rent in south america.
# %%sql
CREATE DATABASE propertyrent 
WITH 
   ENCODING = 'UTF8'
   OWNER = postgres
   CONNECTION LIMIT = 100;

#Create table property_rent_south_america_2017 and import the table to postgres data base.
create table property_rent_south_america_2017(
    created_on date,
    operation text,
    property_type text,
    place_name text,
    country_name text,
    state_name text,
    geonames_id integer,
    lat_lon point,
    lat numeric,
    lon numeric,
    currency text,
    price_local_currency numeric,
    price_aprox_local_currency numeric,
    price_aprox_usd numeric
);

COPY property_rent_south_america_2017 FROM 'C:/Program Files/PostgreSQL/15/data/projects/property_rent_south_america_2017.csv' WITH (FORMAT csv, HEADER true);

# %% [markdown]
# The database will be loaded to the python notebook for EDA.

# %%
# %load_ext sql
import psycopg2

# %sql postgresql://postgres:Calion12.@localhost:5432/propertyrent
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### Preview 10 records from the property_rent_south_america_2017 table

# %%
# %%sql
# SELECT *
# FROM property_rent_south_america_2017
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/propertyrent
# 10 rows affected.
# [(datetime.date(2017, 1, 20), 'Rent', 'Store', 'Chubut', 'Argentina', 'Chubut', 3861244, '(-42.7689857,-65.0363922)', Decimal('-42.7689857'), Decimal('-65.0363922'), 'ARS', Decimal('6000'), Decimal('6270.67'), Decimal('392.69')),
#  (datetime.date(2017, 1, 20), 'Rent', 'Store', 'Chubut', 'Argentina', 'Chubut', 3861244, '(-42.7854486,-65.0559243)', Decimal('-42.7854486'), Decimal('-65.0559243'), 'ARS', Decimal('9000'), Decimal('9052.7'), Decimal('566.91')),
#  (datetime.date(2017, 1, 22), 'Rent', 'Store', 'Chubut', 'Argentina', 'Chubut', 3861244, '(-42.7743988,-65.0522117)', Decimal('-42.7743988'), Decimal('-65.0522117'), 'ARS', Decimal('13000'), Decimal('13076.12'), Decimal('818.87')),
#  (datetime.date(2017, 1, 20), 'Rent', 'Store', 'Chubut', 'Argentina', 'Chubut', 3861244, '(-42.7815348,-65.0320983)', Decimal('-42.7815348'), Decimal('-65.0320983'), 'ARS', Decimal('5400'), Decimal('5652.84'), Decimal('354')),
#  (datetime.date(2017, 1, 20), 'Rent', 'Store', 'Chubut', 'Argentina', 'Chubut', 3861244, '(-42.7751534,-65.0432537)', Decimal('-42.7751534'), Decimal('-65.0432537'), 'ARS', Decimal('7000'), Decimal('7040.99'), Decimal('440.93')),
#  (datetime.date(2016, 12, 21), 'Rent', 'Apartment', 'Chubut', 'Argentina', 'Chubut', 3861244, '(-42.7676381,-65.0442073)', Decimal('-42.7676381'), Decimal('-65.0442073'), 'ARS', Decimal('8500'), Decimal('8549.69'), Decimal('535.41')),
#  (datetime.date(2017, 1, 8), 'Rent', 'Apartment', 'Chubut', 'Argentina', 'Chubut', 3861244, '(-42.7870163,-65.0187351)', Decimal('-42.7870163'), Decimal('-65.0187351'), 'ARS', Decimal('13000'), Decimal('13076.12'), Decimal('818.87')),
#  (datetime.date(2016, 12, 21), 'Rent', 'Apartment', 'Chubut', 'Argentina', 'Chubut', 3861244, '(-42.7716704,-65.0289655)', Decimal('-42.7716704'), Decimal('-65.0289655'), 'ARS', Decimal('17500'), Decimal('17602.39'), Decimal('1102.32')),
#  (datetime.date(2017, 1, 30), 'Rent', 'Apartment', 'Mendoza', 'Argentina', 'Mendoza', 3844419, '(-32.8875241,-68.8336848)', Decimal('-32.8875241'), Decimal('-68.8336848'), 'ARS', Decimal('6500'), Decimal('6537.98'), Decimal('409.43')),
#  (datetime.date(2017, 1, 16), 'Rent', 'Ph', 'Córdoba', 'Argentina', 'Córdoba', 3860255, '(-31.4179699,-64.2053844)', Decimal('-31.4179699'), Decimal('-64.2053844'), 'ARS', Decimal('3600'), Decimal('3740.78'), Decimal('234.26'))]

# %% [markdown]
# ###  Retrieve the average price in the local currency for each country

# %%
# %%sql
#
# SELECT country_name AS country, ROUND(AVG(price_local_currency), 0) AS avg_price
# FROM property_rent_south_america_2017
# GROUP BY 1
# ORDER BY 2 DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/propertyrent
# 7 rows affected.
# [('Colombia', Decimal('4926439')),
#  ('Chile', Decimal('755286')),
#  ('México', Decimal('20458')),
#  ('Uruguay', Decimal('13353')),
#  ('Argentina', Decimal('11140')),
#  ('Perú', Decimal('4189')),
#  ('Brasil', Decimal('3783'))]

# %% [markdown]
# Colombia has the highest average price in the year 2017 followed by Chile and then Mexico.

# %% [markdown]
# ###  Retrieve the average price in the local currency for each property type in each country.

# %%
# %%sql
#
# SELECT country_name AS country, property_type AS type, ROUND(AVG(price_local_currency), 0) AS avg_price
# FROM property_rent_south_america_2017
# GROUP BY 1, 2
# ORDER BY 1, 3 DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/propertyrent
# 25 rows affected.
# [('Argentina', 'Store', Decimal('24252')),
#  ('Argentina', 'House', Decimal('12623')),
#  ('Argentina', 'Ph', Decimal('10672')),
#  ('Argentina', 'Apartment', Decimal('6174')),
#  ('Brasil', 'House', Decimal('3875')),
#  ('Brasil', 'Ph', Decimal('3163')),
#  ('Brasil', 'Store', Decimal('3096')),
#  ('Brasil', 'Apartment', Decimal('2241')),
#  ('Chile', 'House', Decimal('911595')),
#  ('Chile', 'Store', Decimal('865781')),
#  ('Chile', 'Apartment', Decimal('617206')),
#  ('Colombia', 'House', Decimal('6827368')),
#  ('Colombia', 'Store', Decimal('3801196')),
#  ('Colombia', 'Apartment', Decimal('2912007')),
#  ('México', 'Ph', Decimal('36889')),
#  ('México', 'Store', Decimal('29439')),
#  ('México', 'House', Decimal('20024')),
#  ('México', 'Apartment', Decimal('18431')),
#  ('Perú', 'Store', Decimal('5125')),
#  ('Perú', 'House', Decimal('3938')),
#  ('Perú', 'Apartment', Decimal('1658')),
#  ('Uruguay', 'Store', Decimal('28420')),
#  ('Uruguay', 'Ph', Decimal('17389')),
#  ('Uruguay', 'Apartment', Decimal('13143')),
#  ('Uruguay', 'House', Decimal('10224'))]

# %% [markdown]
# ###  Retrieve the total price in USD currency for each property type.

# %%
# %%sql
#
# SELECT property_type AS type, ROUND(SUM(price_local_currency), 0) AS total_price
# FROM property_rent_south_america_2017
# GROUP BY 1
# ORDER BY 2 DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/propertyrent
# 4 rows affected.
# [('House', Decimal('7002148340')),
#  ('Apartment', Decimal('2865637154')),
#  ('Store', Decimal('1652516442')),
#  ('Ph', Decimal('23545150'))]

# %% [markdown]
# The house property type had the highest total cost in the stated countries above.

# %% [markdown]
# ### Retrieve the properties with the highest price in each country.

# %%
# %%sql
#
# WITH max_prices AS (
#   SELECT country_name, MAX(price_aprox_usd) AS max_price_usd
#   FROM property_rent_south_america_2017
#   GROUP BY country_name
# )
# SELECT p.country_name AS country, p.property_type AS type, ROUND(m.max_price_usd, 0) AS highest_price
# FROM property_rent_south_america_2017 AS p
# JOIN max_prices AS m
# ON p.country_name = m.country_name AND p.price_aprox_usd = m.max_price_usd
# GROUP BY 1, 2, 3
# ORDER BY 3 DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/propertyrent
# 7 rows affected.
# [('Perú', 'Apartment', Decimal('98000')),
#  ('Chile', 'Apartment', Decimal('94273')),
#  ('México', 'House', Decimal('88685')),
#  ('Brasil', 'House', Decimal('88560')),
#  ('Colombia', 'House', Decimal('66580')),
#  ('Argentina', 'Ph', Decimal('62000')),
#  ('Uruguay', 'House', Decimal('50000'))]

# %% [markdown]
# ### Retrieve the properties where the price in the local currency is above the average price for the respective property type.

# %%
# %%sql
#
# SELECT p.country_name AS country, p.property_type AS type
# FROM property_rent_south_america_2017 AS p
# WHERE p.price_local_currency > (
#   SELECT AVG(price_local_currency)
#   FROM property_rent_south_america_2017
#   WHERE property_type = p.property_type
# )
# GROUP BY 1, 2;
# Out:
#  * postgresql://postgres:***@localhost:5432/propertyrent
# 13 rows affected.
# [('Argentina', 'Ph'),
#  ('Brasil', 'Ph'),
#  ('Chile', 'Apartment'),
#  ('Chile', 'House'),
#  ('Chile', 'Store'),
#  ('Colombia', 'Apartment'),
#  ('Colombia', 'House'),
#  ('Colombia', 'Store'),
#  ('México', 'Apartment'),
#  ('México', 'House'),
#  ('México', 'Ph'),
#  ('México', 'Store'),
#  ('Uruguay', 'Ph')]
